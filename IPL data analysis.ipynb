# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ipl=pd.read_csv('C:\python tutorial\python project\IPL Data Analysis Using Python 2022\ipl_2022_dataset.csv')

# %%
ipl.head()
# Out:
#    Unnamed: 0           Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           0      Rashid Khan  Draft Pick       BOWLER             15.0
# 1           1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           2  Lockie Ferguson        2 Cr       BOWLER             10.0
# 3           3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4           4     Shubman Gill  Draft Pick       BATTER              8.0
#
#    Cost IN $ (000) 2021 Squad            Team
# 0           1950.0        SRH  Gujarat Titans
# 1           1950.0         MI  Gujarat Titans
# 2           1300.0        KKR  Gujarat Titans
# 3           1170.0         RR  Gujarat Titans
# 4           1040.0        KKR  Gujarat Titans

# %%
ipl.shape
# Out:
# (633, 8)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       633 non-null    int64
#  1   Player           633 non-null    object
#  2   Base Price       633 non-null    object
#  3   TYPE             633 non-null    object
#  4   COST IN ₹ (CR.)  237 non-null    float64
#  5   Cost IN $ (000)  237 non-null    float64
#  6   2021 Squad       199 non-null    object
#  7   Team             633 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 39.7+ KB

# %%
ipl.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)',
#        'Cost IN $ (000)', '2021 Squad', 'Team'],
#       dtype='object')

# %%
ipl.drop('Unnamed: 0', axis=1, inplace=True)

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team
# 0        SRH  Gujarat Titans
# 1         MI  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3         RR  Gujarat Titans
# 4        KKR  Gujarat Titans

# %%
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    396
# Cost IN $ (000)    396
# 2021 Squad         434
# Team                 0
# dtype: int64

# %%
ipl[ipl['Cost IN $ (000)'].isnull()]
# Out:
#                      Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 237            Suresh Raina       2 Cr       BATTER              NaN
# 238             Steve Smith       2 Cr       BATTER              NaN
# 239         Shakib Al Hasan       2 Cr  ALL-ROUNDER              NaN
# 240             Amit Mishra     1.5 Cr       BOWLER              NaN
# 241             Adil Rashid       2 Cr       BOWLER              NaN
# ..                      ...        ...          ...              ...
# 628            Sairaj Patil    20 Lakh       BATTER              NaN
# 629              Monu Singh    20 Lakh       BOWLER              NaN
# 630  Nivethan Radhakrishnan    20 Lakh       BOWLER              NaN
# 631            Lance Morris    20 Lakh       BOWLER              NaN
# 632            Aaron Hardie    20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad    Team
# 237              NaN        CSK  Unsold
# 238              NaN         DC  Unsold
# ...

# %%
ipl['Cost IN $ (000)'] = ipl['Cost IN $ (000)'].fillna(0)
ipl['COST IN ₹ (CR.)'] = ipl['COST IN ₹ (CR.)'].fillna(0)

# %%
ipl[ipl['2021 Squad'].isnull()]
# Out:
#                      Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 6                Yash Dayal    20 Lakh        BOWLER              3.2
# 9       Abhinav Sadarangani    20 Lakh        BATTER              2.6
# 10             Matthew Wade       2 Cr  WICKETKEEPER              2.4
# 11           Alzarri Joseph    75 Lakh        BOWLER              2.4
# 17              Varun Aaron    50 Lakh        BOWLER              0.5
# ..                      ...        ...           ...              ...
# 628            Sairaj Patil    20 Lakh        BATTER              0.0
# 629              Monu Singh    20 Lakh        BOWLER              0.0
# 630  Nivethan Radhakrishnan    20 Lakh        BOWLER              0.0
# 631            Lance Morris    20 Lakh        BOWLER              0.0
# 632            Aaron Hardie    20 Lakh   ALL-ROUNDER              0.0
#
#      Cost IN $ (000) 2021 Squad            Team
# 6              416.0        NaN  Gujarat Titans
# ...

# %%
ipl['2021 Squad'] = ipl['2021 Squad'].fillna('not participated')

# %%
ipl.isnull().sum()
# Out:
# Player             0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2021 Squad         0
# Team               0
# dtype: int64

# %%
teams = ipl[ipl['COST IN ₹ (CR.)']>0]['Team'].unique()
teams
# Out:
# array(['Gujarat Titans', 'Chennai Super Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Lucknow Super Giants',
#        'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Rajasthan Royals', 'Sunrisers Hyderabad'], dtype=object)

# %%
ipl['status'] = ipl['Team'].replace(teams,'sold')

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team status
# 0        SRH  Gujarat Titans   sold
# 1         MI  Gujarat Titans   sold
# 2        KKR  Gujarat Titans   sold
# 3         RR  Gujarat Titans   sold
# 4        KKR  Gujarat Titans   sold

# %%
ipl[ipl['Player'].duplicated(keep=False)]
# Out:
#             Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 62     Lalit Yadav    20 Lakh  ALL-ROUNDER             0.65             84.5
# 240    Amit Mishra     1.5 Cr       BOWLER             0.00              0.0
# 499    Amit Mishra    20 Lakh       BOWLER             0.00              0.0
# 518  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
# 530    Lalit Yadav    20 Lakh       BOWLER             0.00              0.0
# 537  Shubham Singh    20 Lakh  ALL-ROUNDER             0.00              0.0
# 544  Shubham Singh    20 Lakh       BOWLER             0.00              0.0
# 569  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
#
#            2021 Squad            Team  status
# 62                 DC  Delhi Capitals    sold
# 240                DC          Unsold  Unsold
# 499  not participated          Unsold  Unsold
# 518  not participated          Unsold  Unsold
# ...

# %%
# how many players have participated in 2022 auction ?
ipl.shape[0]
# Out:
# 633

# %%
# how many types of players have participated ?
types = ipl['TYPE'].value_counts()
types.reset_index()
# Out:
#           index  TYPE
# 0   ALL-ROUNDER   242
# 1        BOWLER   215
# 2        BATTER   112
# 3  WICKETKEEPER    64

# %%
plt.pie(types.values, labels = types.index, labeldistance=1.2,autopct='%1.2f%%', shadow=True, startangle=60)
plt.title('Role of players participated',fontsize = 15)
plt.plot()
# Out:
# []

# %%
# players sold and unsold using bae graph
plt.figure(figsize=(10,5))
fig = sns.countplot(ipl['status'],palette=['Green','Red'])
plt.xlabel('Sold or Unsold')
plt.ylabel('Number of Players')
plt.title('Sold vs Unsold', fontsize=15)
plt.plot()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width()/2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 4), textcoords = 'offset points')

# %%
ipl.groupby('status')['Player'].count()
# Out:
# status
# Unsold    396
# sold      237
# Name: Player, dtype: int64

# %%
 # How many Players Brought by Each Team
plt.figure(figsize=(20,10))
fig = sns.countplot(ipl[ipl['Team']!='Unsold']['Team'])
plt.xlabel('Team names')
plt.ylabel('Number of Players')
plt.title('Players Brought by each Team', fontsize=12)
plt.xticks(rotation=60)
plt.plot()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width()/2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 4), textcoords = 'offset points')

# %%
ipl['retention'] = ipl['Base Price']

# %%
ipl['retention'].replace(['2 Cr', '40 Lakh', '20 Lakh', '1 Cr', '75 Lakh',
       '50 Lakh', '30 Lakh','1.5 Cr'],'In Auction', inplace = True)

# %%
# Treating Base Price Column
ipl['Base Price'].replace('Draft Pick',0, inplace = True)

# %%
ipl['base_price_unit'] = ipl['Base Price'].apply(lambda x: str(x).split(' ')[-1])
ipl['base_price'] = ipl['Base Price'].apply(lambda x: str(x).split(' ')[0])

# %%
ipl['base_price'].replace('Retained',0,inplace=True)

# %%
ipl.head()
# Out:
#             Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan          0       BOWLER             15.0           1950.0
# 1    Hardik Pandya          0  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson       2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia    40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill          0       BATTER              8.0           1040.0
#
#   2021 Squad            Team status   retention base_price_unit base_price
# 0        SRH  Gujarat Titans   sold  Draft Pick               0          0
# 1         MI  Gujarat Titans   sold  Draft Pick               0          0
# 2        KKR  Gujarat Titans   sold  In Auction              Cr          2
# 3         RR  Gujarat Titans   sold  In Auction            Lakh         40
# 4        KKR  Gujarat Titans   sold  Draft Pick               0          0

# %%
# How many players Retained/DraftPicked by Each team ?
ipl.groupby(['Team','retention'])['retention'].count()[:-1]
# Out:
# Team                         retention
# Chennai Super Kings          In Auction    21
#                              Retained       4
# Delhi Capitals               In Auction    20
#                              Retained       4
# Gujarat Titans               Draft Pick     3
#                              In Auction    19
# Kolkata Knight Riders        In Auction    21
#                              Retained       4
# Lucknow Super Giants         Draft Pick     3
#                              In Auction    19
# Mumbai Indians               In Auction    21
#                              Retained       4
# Punjab Kings                 In Auction    23
#                              Retained       2
# Rajasthan Royals             In Auction    21
#                              Retained       3
# Royal Challengers Bangalore  In Auction    19
#                              Retained       3
# Sunrisers Hyderabad          In Auction    20
# ...

# %%
# Number of players in each team based on thier roles
plt.figure(figsize=(20,10))
fig = sns.countplot(ipl[ipl['Team']!='Unsold']['Team'],hue=ipl['TYPE'])
plt.title('Players in Each Team')
plt.xlabel('Team Names')
plt.ylabel('Number of Player')

plt.xticks(rotation = 60)

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width()/2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 4), textcoords = 'offset points')

# %%
#  Which Are the players who participated in IPL 2021 and will be participating in IPL 2022 and playing in same team
ipl.replace({'SRH':'Sunrisers Hyderabad','CSK':'Chennai Super Kings','MI':'Mumbai Indians','KKR':'Kolkata Knight Riders','RR':'Rajasthan Royals','PBKS':'Punjab Kings','DC':'Delhi Capitals','RCB':'Royal Challengers Bangalore'},inplace =True)

# %%
same_team = ipl[(ipl['Team']==ipl['2021 Squad']) & (ipl['retention']=='In Auction')]
same_team
# Out:
#                   Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 23         Deepak Chahar       2 Cr        BOWLER            14.00
# 26         Ambati Rayudu       2 Cr  WICKETKEEPER             6.75
# 28          Dwayne Bravo       2 Cr   ALL-ROUNDER             4.40
# 31         Robin Uthappa       2 Cr        BATTER             2.00
# 32      Mitchell Santner       1 Cr   ALL-ROUNDER             1.90
# 39       K.Bhagath Varma    20 Lakh   ALL-ROUNDER             0.20
# 41         N. Jagadeesan    20 Lakh  WICKETKEEPER             0.20
# 42      C.Hari Nishaanth    20 Lakh        BATTER             0.20
# 43             K.M. Asif    20 Lakh        BOWLER             0.20
# 62           Lalit Yadav    20 Lakh   ALL-ROUNDER             0.65
# 64          Pravin Dubey    20 Lakh   ALL-ROUNDER             0.50
# 69           Ripal Patel    20 Lakh   ALL-ROUNDER             0.20
# 73           Nitish Rana       1 Cr   ALL-ROUNDER             8.00
# ...

# %%
#  Heighest Bid(successful ) by each team
ipl[ipl['retention']=='In Auction'].groupby(['Team'])['Cost IN $ (000)'].max()[:-1].sort_values(ascending = False)
# Out:
# Team
# Mumbai Indians                 1982.5
# Chennai Super Kings            1820.0
# Kolkata Knight Riders          1592.5
# Punjab Kings                   1495.0
# Delhi Capitals                 1397.5
# Royal Challengers Bangalore    1397.5
# Sunrisers Hyderabad            1397.5
# Gujarat Titans                 1300.0
# Lucknow Super Giants           1300.0
# Rajasthan Royals               1300.0
# Name: Cost IN $ (000), dtype: float64

# %%
#  Heighest Paid Retained player
ipl[ipl['retention']=='Retained'].sort_values(by = 'Cost IN $ (000)', ascending = False).head(1)
# Out:
#              Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 22  Ravindra Jadeja   Retained  ALL-ROUNDER             16.0           2080.0
#
#              2021 Squad                 Team status retention base_price_unit  \
# 22  Chennai Super Kings  Chennai Super Kings   sold  Retained        Retained
#
#    base_price
# 22          0

# %%
# Top Five Batsman picked from Auction
ipl[(ipl['retention']=='In Auction') & (ipl['TYPE']=='BATTER')].sort_values(by='Cost IN $ (000)', ascending = False).head(5)
# Out:
#                Player Base Price    TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 71       Shreyas Iyer       2 Cr  BATTER            12.25           1592.5
# 193   Shimron Hetmyer     1.5 Cr  BATTER             8.50           1105.0
# 217    Rahul Tripathi    40 Lakh  BATTER             8.50           1105.0
# 100    Shikhar Dhawan       2 Cr  BATTER             8.25           1072.5
# 195  Devdutt Padikkal       2 Cr  BATTER             7.75           1007.5
#
#                       2021 Squad                   Team status   retention  \
# 71                Delhi Capitals  Kolkata Knight Riders   sold  In Auction
# 193               Delhi Capitals       Rajasthan Royals   sold  In Auction
# 217        Kolkata Knight Riders    Sunrisers Hyderabad   sold  In Auction
# 100               Delhi Capitals           Punjab Kings   sold  In Auction
# 195  Royal Challengers Bangalore       Rajasthan Royals   sold  In Auction
#
#     base_price_unit base_price
# 71               Cr          2
# ...

# %%
# Top Five Bowler picked from Auction
ipl[(ipl['retention']=='In Auction') & (ipl['TYPE']=='BOWLER')].sort_values(by='COST IN ₹ (CR.)', ascending = False).head(5)
# Out:
#               Player Base Price    TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 23     Deepak Chahar       2 Cr  BOWLER            14.00           1820.0
# 48    Shardul Thakur       2 Cr  BOWLER            10.75           1397.5
# 192  Prasidh Krishna       1 Cr  BOWLER            10.00           1300.0
# 2    Lockie Ferguson       2 Cr  BOWLER            10.00           1300.0
# 122       Avesh Khan    20 Lakh  BOWLER            10.00           1300.0
#
#                 2021 Squad                  Team status   retention  \
# 23     Chennai Super Kings   Chennai Super Kings   sold  In Auction
# 48     Chennai Super Kings        Delhi Capitals   sold  In Auction
# 192  Kolkata Knight Riders      Rajasthan Royals   sold  In Auction
# 2    Kolkata Knight Riders        Gujarat Titans   sold  In Auction
# 122         Delhi Capitals  Lucknow Super Giants   sold  In Auction
#
#     base_price_unit base_price
# 23               Cr          2
# 48               Cr          2
# ...

# %%
# Top Five All rounder picked from Auction
ipl[(ipl['retention']=='In Auction') & (ipl['TYPE']=='ALL-ROUNDER')].sort_values(by='COST IN ₹ (CR.)', ascending = False).head(5)
# Out:
#                 Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 97    Liam Livingstone       1 Cr  ALL-ROUNDER            11.50
# 170  Wanindu Hasaranga       1 Cr  ALL-ROUNDER            10.75
# 171      Harshal Patel       2 Cr  ALL-ROUNDER            10.75
# 99       Shahrukh Khan    40 Lakh  ALL-ROUNDER             9.00
# 3        Rahul Tewatia    40 Lakh  ALL-ROUNDER             9.00
#
#      Cost IN $ (000)                   2021 Squad  \
# 97            1495.0             Rajasthan Royals
# 170           1397.5  Royal Challengers Bangalore
# 171           1397.5  Royal Challengers Bangalore
# 99            1170.0                 Punjab Kings
# 3             1170.0             Rajasthan Royals
#
#                             Team status   retention base_price_unit base_price
# 97                  Punjab Kings   sold  In Auction              Cr          1
# 170  Royal Challengers Bangalore   sold  In Auction              Cr          1
# ...

# %%
# List of players who Played IPL 2021 but went unsold this time
unsold_stars = ipl[(ipl.Team != 'Not Participated in IPL 2021') & (ipl.Team == 'Unsold')][['Player','2021 Squad']]
unsold_stars
# Out:
#                      Player             2021 Squad
# 237            Suresh Raina    Chennai Super Kings
# 238             Steve Smith         Delhi Capitals
# 239         Shakib Al Hasan  Kolkata Knight Riders
# 240             Amit Mishra         Delhi Capitals
# 241             Adil Rashid           Punjab Kings
# ..                      ...                    ...
# 628            Sairaj Patil       not participated
# 629              Monu Singh       not participated
# 630  Nivethan Radhakrishnan       not participated
# 631            Lance Morris       not participated
# 632            Aaron Hardie       not participated
#
# [396 rows x 2 columns]

# %%
unsold_stars.groupby('2021 Squad')['Player'].count()
# Out:
# 2021 Squad
# Chennai Super Kings              3
# Delhi Capitals                   7
# Kolkata Knight Riders            5
# Mumbai Indians                   6
# Punjab Kings                     5
# Rajasthan Royals                 3
# Royal Challengers Bangalore      7
# Sunrisers Hyderabad              4
# not participated               356
# Name: Player, dtype: int64
